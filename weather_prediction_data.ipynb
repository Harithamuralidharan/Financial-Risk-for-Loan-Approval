# %% [markdown]
# <a href="https://colab.research.google.com/github/Harithamuralidharan/weather_Prediction/blob/main/weather_prediction_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv("weather_data.csv")
data.head(5)
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0      73.0         9.5               82.0  partly cloudy
# 1         39.0       NaN         8.5               71.0            NaN
# 2         30.0      64.0         7.0               16.0          clear
# 3         38.0      83.0         1.5               82.0          clear
# 4         27.0      74.0        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82       2.0  Winter              3.5    inland
# 1               1011.43       7.0  Spring             10.0    inland
# 2                   NaN       5.0  Spring              5.5  mountain
# 3               1026.25       7.0  Spring              1.0   coastal
# 4                990.67       1.0  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
data.shape
# Out:
# (13200, 11)

# %%
data.isnull().sum()
# Out:
# Temperature             1261
# Humidity                1278
# Wind Speed              1261
# Precipitation (%)       1234
# Cloud Cover             1220
# Atmospheric Pressure    1276
# UV Index                1252
# Season                     0
# Visibility (km)         1237
# Location                1265
# Weather Type               0
# dtype: int64
