# %% [markdown]
# <a href="https://colab.research.google.com/github/Harithamuralidharan/Financial-Risk-for-Loan-Approval/blob/main/Financial_Risk_For_Loan_Approvel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   # **Financial Risk For Loan Approval**

# %% [markdown]
# ## **Introduction**
# *The fast moving financial world,bank and lending instutions face the constant challenge of approving loans minimizing financial risk.A wrong decision either approving a risk borrower or rejecting a reliable one can have serious consequences. To tackle this,lenders use **data_driven risk assessment** to make smarter,more informed loan approval decisions.This dataset contains crucial financial and personal details about loan applicants,including their **credit history,income,debts,assets and employment status**. By analysing these factors we can predict whether the applicant's to **repay the loan on time or default**.*

# %% [markdown]
# ## **Problem Statement**
#
# *Loan default can be a major problem for financial institutions, leading to significant losses.The challenge is to accurately **identify risk borrowers** while ensuring that deserving applicants get access to credit.Traditional credit scoring methods often miss key financial behaviors, and manual assessment can be biased or inconsistent.The goal of this project is to **develop a reliable risk assessment model** that can predict loan approvel
# based on historical applicant data.By leveraging machine learning and data analytics, we aim to reduce bad loans, improve lending efficiency, and create a more transparent and fair loan approval process.*
#
# ## **Core Stages and component**
#
#
# *   Exploratory Data Analysis**(EDA)**
# *   Data Preprocessing-Data cleaning
# *   Handling Missing values
# *   Feature Engineering
# *   Feature selection
# *   Feature Scaling
# *   Spliting data for train and test
# *   Machine learning model building
# *   model evaluation

# %% [markdown]
# ## **variables:**
#
#
#
# |**s.no**|**Variable Name**              |**Role**               |**type**      |**Decription**
# |--|--------------------------|-------------------|----------|----------
# |1.|Age                        |feature            |Continuos|Applicant's age
# |2.|AnnualIncome               |Feature            |Continuos|Yearly income
# |3.|CreditScore                |Feature            |Continuos|Creditworthiness score
# |4.|EmploymentStatus           |Feature            |Categorical|Job situation
# |5.|EducationLevel             |Feature            |Categorical|Highest education attained
# |6.|Experiance                 |Feature            |Continuos|work experience
# |7.|LoanAmount                 |Feature            |Continuos|Requested loan size
# |8.|LoanDuration               |Feature            |Continuos|Loan repayment period
# |9.|MaritalStatus              |Feature            |Categorical|Applicant's marial state
# |10.|NumberOfDependents        |Feature            |Continuos|Number of dependents
# |11.|HomeOwnershipStatus       |Feature            |Categorical|Homeownership type
# |12.|MonthlyDebtPayment        |Feature            |Continuos|Monthly debt obligations
# |13.|CreditCard UtilizationRate|Feature            |Continuos|Credit care usage percentage
# |14.|NumberOfOpenCreditLines   |Feature            |Continuos |Active credit lines
# |15.|NumberOfCreditlnquiries   |Feature            | Continuos |Credit check count
# |16.|DebtToIncomeRatio         |Feature            |Continuos|Debit to income proportion
# |17.|BankruptcyHistory         |Feature             | Categorical |Bankruptcy records
# |18.|LoanPurpose               |Feature             |Continuos|Reason for loan
# |19.|PreviousLoanDefaults      |Feature             |Continuos|Prior loan defaults
# |20.|PaymentHistory            |Feature             |Continuos|Past pyment behavior
# |21.|LengthOfCreditHistory     |Feature             |Continuos|Credit history duration
# |22.|SavingsAccountBalance     |Feature              |Continuos|Savings account amount
# |23.|CheckingAccountBalance    |Feature            |Continuos|Checking account fund
# |24.|TotalAssets               |Feature            |Continuos|Total owned assets
# |25.|TotalLiabilities          |Feature            |Continuos|Total owed debts
# |26.|MonthlyIncome             |Feature            |Continuos|Income per month
# |27.|UtilityBillsPaymentHistory|Feature            |Continuos|Utility payment record
# |28.|JobTenure                 |Feature            |Continuos|Job duration
# |29.|NetWorth                  |Feature            |Continuos|Total financial worth
# |30.|BaselnterestRate          |Feature            |Continuos| Starting interest rate
# |31.|InterestRate              |Feature            |Continuos|Applied interest rate
# |32.|MonthlyLoanPayment        |Feature            |Continuos|Monthly loan payment
# |33.|TotalDebtToIncomeRatio    |Feature            |Continuos|Total debt against income
# |34.|LoanApproved              |Target             |Continuos|Loan approval status
# |35.|RiskScore                 |Feature            |Continuos|Risk assessment score

# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

#loading the dataset
data = pd.read_csv("Loan.csv")

# %% [markdown]
# ### **Initial Exploratory Data Analysis(EDA)**

# %%
# view the top 5 rows in dataset
data.head(5)
# Out:
#     Age  AnnualIncome  CreditScore EmploymentStatus EducationLevel  \
# 0  45.0       39948.0          617         Employed         Master
# 1  38.0       39709.0          628         Employed      Associate
# 2  47.0       40724.0          570         Employed       Bachelor
# 3   NaN       69084.0          545         Employed    High School
# 4  37.0      103264.0          594         Employed      Associate
#
#    Experience  LoanAmount  LoanDuration MaritalStatus  NumberOfDependents  \
# 0        22.0     13152.0          48.0       Married                 NaN
# 1        15.0     26045.0           NaN        Single                 1.0
# 2        26.0         NaN           NaN       Married                 2.0
# 3        34.0     37898.0          96.0        Single                 1.0
# 4        17.0      9184.0          36.0       Married                 NaN
#
#    ... MonthlyIncome  UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0  ...           NaN                    0.724972       11.0  126928.0
# 1  ...   3309.083333                         NaN        3.0   43609.0
# 2  ...           NaN                    0.872241        6.0    5205.0
# 3  ...   5757.000000                    0.896155        5.0   99452.0
# 4  ...   8605.333333                    0.941369        5.0  227019.0
#
#    BaseInterestRate  InterestRate  MonthlyLoanPayment TotalDebtToIncomeRatio  \
# 0          0.199652      0.227590          419.805992               0.181077
# 1          0.207045      0.201077          794.054238               0.389852
# 2          0.217627      0.212548                 NaN                    NaN
# 3          0.300398      0.300911         1047.506980               0.313098
# 4          0.197184      0.175990          330.179141                    NaN
#
#    LoanApproved  RiskScore
# 0             0       49.0
# 1             0       52.0
# 2             0       52.0
# 3             0       54.0
# 4             1       36.0
#
# [5 rows x 35 columns]

# %%
#view the bottom 5 rows in dataset
data.tail(5)
# Out:
#         Age  AnnualIncome  CreditScore EmploymentStatus EducationLevel  \
# 19995  44.0       30180.0          587         Employed    High School
# 19996  56.0       49246.0          567         Employed      Associate
# 19997  44.0       48958.0          645         Employed       Bachelor
# 19998  60.0       41025.0          560         Employed    High School
# 19999  20.0       53227.0          574         Employed      Associate
#
#        Experience  LoanAmount  LoanDuration MaritalStatus  NumberOfDependents  \
# 19995        19.0     24521.0          36.0       Married                 3.0
# 19996        33.0     25818.0          36.0       Married                 5.0
# 19997        20.0     37033.0          72.0       Married                 3.0
# 19998        36.0     14760.0          72.0           NaN                 3.0
# 19999         0.0     32055.0          48.0       Married                 NaN
#
#        ... MonthlyIncome  UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 19995  ...   2515.000000                    0.826217        1.0   55327.0
# 19996  ...   4103.833333                    0.816618        3.0   64002.0
# 19997  ...           NaN                    0.887216        3.0  103663.0
# 19998  ...   3418.750000                    0.843787        5.0   10600.0
# 19999  ...           NaN                    0.853801        5.0   41372.0
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 19995          0.216021      0.195574          905.767712
# 19996          0.227318      0.199168          958.395633
# 19997          0.229533      0.226766          945.427454
# 19998          0.249760      0.264873          411.168284
# 19999          0.240055      0.242693         1049.830407
#
#       TotalDebtToIncomeRatio  LoanApproved  RiskScore
# 19995               0.627741             0       55.0
# 19996               0.334418             0       54.0
# 19997               0.357227             0       45.0
# 19998               0.408678             0       59.0
# 19999               0.298006             0       59.0
#
# [5 rows x 35 columns]

# %%
#Detail over view of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         18251 non-null  float64
#  1   AnnualIncome                18719 non-null  float64
#  2   CreditScore                 20000 non-null  int64
#  3   EmploymentStatus            17263 non-null  object
#  4   EducationLevel              18303 non-null  object
#  5   Experience                  17396 non-null  float64
#  6   LoanAmount                  18847 non-null  float64
#  7   LoanDuration                18611 non-null  float64
#  8   MaritalStatus               17003 non-null  object
#  9   NumberOfDependents          17146 non-null  float64
#  10  HomeOwnershipStatus         18862 non-null  object
#  11  MonthlyDebtPayments         18213 non-null  float64
#  12  CreditCardUtilizationRate   18621 non-null  float64
#  13  NumberOfOpenCreditLines     18586 non-null  float64
#  14  NumberOfCreditInquiries     18366 non-null  float64
#  15  DebtToIncomeRatio           17906 non-null  float64
#  16  BankruptcyHistory           17466 non-null  float64
#  17  LoanPurpose                 18963 non-null  object
#  18  PreviousLoanDefaults        17541 non-null  float64
#  19  PaymentHistory              17589 non-null  float64
#  20  LengthOfCreditHistory       18300 non-null  float64
#  21  SavingsAccountBalance       18007 non-null  float64
#  22  CheckingAccountBalance      18123 non-null  float64
#  23  TotalAssets                 18781 non-null  float64
#  24  TotalLiabilities            17592 non-null  float64
#  25  MonthlyIncome               17928 non-null  float64
#  26  UtilityBillsPaymentHistory  18712 non-null  float64
#  27  JobTenure                   18862 non-null  float64
#  28  NetWorth                    17777 non-null  float64
#  29  BaseInterestRate            18163 non-null  float64
#  30  InterestRate                17287 non-null  float64
#  31  MonthlyLoanPayment          18846 non-null  float64
#  32  TotalDebtToIncomeRatio      18109 non-null  float64
#  33  LoanApproved                20000 non-null  int64
#  34  RiskScore                   20000 non-null  float64
# dtypes: float64(28), int64(2), object(5)
# memory usage: 5.3+ MB

# %%
#Return the number of records and features in tuple
data.shape
# Out:
# (20000, 35)

# %%
#check the missing values in the data set
data.isnull().sum()
# Out:
# Age                           1749
# AnnualIncome                  1281
# CreditScore                      0
# EmploymentStatus              2737
# EducationLevel                1697
# Experience                    2604
# LoanAmount                    1153
# LoanDuration                  1389
# MaritalStatus                 2997
# NumberOfDependents            2854
# HomeOwnershipStatus           1138
# MonthlyDebtPayments           1787
# CreditCardUtilizationRate     1379
# NumberOfOpenCreditLines       1414
# NumberOfCreditInquiries       1634
# DebtToIncomeRatio             2094
# BankruptcyHistory             2534
# LoanPurpose                   1037
# PreviousLoanDefaults          2459
# PaymentHistory                2411
# LengthOfCreditHistory         1700
# SavingsAccountBalance         1993
# CheckingAccountBalance        1877
# TotalAssets                   1219
# TotalLiabilities              2408
# MonthlyIncome                 2072
# UtilityBillsPaymentHistory    1288
# JobTenure                     1138
# NetWorth                      2223
# BaseInterestRate              1837
# InterestRate                  2713
# MonthlyLoanPayment            1154
# TotalDebtToIncomeRatio        1891
# LoanApproved                     0
# RiskScore                        0
# dtype: int64

# %%
#statistical summary of the dataset
data.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  18251.000000   18719.000000  20000.000000  17396.000000   18847.000000
# mean      39.769876   59126.566697    571.612400     17.526903   24888.323128
# std       11.612307   40345.662812     50.997358     11.339904   13443.215537
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31571.500000    540.000000      9.000000   15593.000000
# 50%       40.000000   48445.000000    578.000000     17.000000   21904.000000
# 75%       48.000000   74374.000000    609.000000     25.000000   30836.500000
# max       80.000000  422480.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  18611.000000        17146.000000         18213.000000
# mean      53.968083            1.520588           454.831384
# std       24.643069            1.389189           241.531978
# min       12.000000            0.000000            60.000000
# 25%       36.000000            0.000000           286.000000
# 50%       48.000000            1.000000           402.000000
# 75%       72.000000            3.000000           564.000000
# max      120.000000            5.000000          2919.000000
#
#        CreditCardUtilizationRate  NumberOfOpenCreditLines  ...  MonthlyIncome  \
# count               18621.000000             18586.000000  ...   17928.000000
# mean                    0.286318                 3.031798  ...    4897.727526
# std                     0.159776                 1.731200  ...    3297.612278
# min                     0.000974                 0.000000  ...    1250.000000
# 25%                     0.160907                 2.000000  ...    2625.770833
# 50%                     0.266493                 3.000000  ...    4044.708333
# 75%                     0.390221                 4.000000  ...    6175.979167
# max                     0.917380                12.000000  ...   25000.000000
#
#        UtilityBillsPaymentHistory     JobTenure      NetWorth  \
# count                18712.000000  18862.000000  1.777700e+04
# mean                     0.799932      5.005779  7.227946e+04
# std                      0.120924      2.236653  1.179878e+05
# min                      0.270036      0.000000  1.000000e+03
# 25%                      0.727258      3.000000  8.739000e+03
# 50%                      0.820795      5.000000  3.289100e+04
# 75%                      0.892627      6.000000  8.841300e+04
# max                      0.999433     16.000000  2.603208e+06
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# count      18163.000000  17287.000000        18846.000000
# mean           0.239137      0.239233          912.013561
# std            0.035633      0.042083          674.887461
# min            0.130101      0.113310           97.030193
# 25%            0.213846      0.209347          494.273727
# 50%            0.236161      0.235679          729.389161
# 75%            0.261634      0.265454         1113.154416
# max            0.405029      0.446787        10892.629520
#
#        TotalDebtToIncomeRatio  LoanApproved     RiskScore
# count            18109.000000  20000.000000  20000.000000
# mean                 0.401987      0.239000     50.766780
# std                  0.340166      0.426483      7.778262
# min                  0.016043      0.000000     28.800000
# 25%                  0.179518      0.000000     46.000000
# 50%                  0.302429      0.000000     52.000000
# 75%                  0.508214      0.000000     56.000000
# max                  4.647657      1.000000     84.000000
#
# [8 rows x 30 columns]

# %%
#check the number of duplicate records

data.duplicated().sum()
# Out:
# 0

# %%
# get all categorial columns in the dataset
cate_col =data.select_dtypes('O').columns.tolist()
cate_col
# Out:
# ['EmploymentStatus',
#  'EducationLevel',
#  'MaritalStatus',
#  'HomeOwnershipStatus',
#  'LoanPurpose']

# %%
#get all numerical columns in the dataset
num_col =data.select_dtypes(include='number').columns.tolist()
num_col
# Out:
# ['Age',
#  'AnnualIncome',
#  'CreditScore',
#  'Experience',
#  'LoanAmount',
#  'LoanDuration',
#  'NumberOfDependents',
#  'MonthlyDebtPayments',
#  'CreditCardUtilizationRate',
#  'NumberOfOpenCreditLines',
#  'NumberOfCreditInquiries',
#  'DebtToIncomeRatio',
#  'BankruptcyHistory',
#  'PreviousLoanDefaults',
#  'PaymentHistory',
#  'LengthOfCreditHistory',
#  'SavingsAccountBalance',
#  'CheckingAccountBalance',
#  'TotalAssets',
#  'TotalLiabilities',
#  'MonthlyIncome',
#  'UtilityBillsPaymentHistory',
#  'JobTenure',
#  'NetWorth',
#  'BaseInterestRate',
#  'InterestRate',
#  'MonthlyLoanPayment',
#  'TotalDebtToIncomeRatio',
#  'LoanApproved',
#  'RiskScore']

# %%
#check the unique value count in the categorical columns

for i in data[cate_col]:
  unique_values= data[cate_col].nunique().to_dict()
unique_values
# Out:
# {'EmploymentStatus': 3,
#  'EducationLevel': 5,
#  'MaritalStatus': 4,
#  'HomeOwnershipStatus': 4,
#  'LoanPurpose': 5}

# %%
#check the unique values count in numerical columns
for i in data[num_col]:
  unique_num=data[num_col].nunique().to_dict()
unique_num
# Out:
# {'Age': 63,
#  'AnnualIncome': 16492,
#  'CreditScore': 322,
#  'Experience': 62,
#  'LoanAmount': 14876,
#  'LoanDuration': 10,
#  'NumberOfDependents': 6,
#  'MonthlyDebtPayments': 1281,
#  'CreditCardUtilizationRate': 18621,
#  'NumberOfOpenCreditLines': 13,
#  'NumberOfCreditInquiries': 8,
#  'DebtToIncomeRatio': 17906,
#  'BankruptcyHistory': 2,
#  'PreviousLoanDefaults': 2,
#  'PaymentHistory': 37,
#  'LengthOfCreditHistory': 29,
#  'SavingsAccountBalance': 8732,
#  'CheckingAccountBalance': 4946,
#  'TotalAssets': 17725,
#  'TotalLiabilities': 15331,
#  'MonthlyIncome': 15832,
#  'UtilityBillsPaymentHistory': 18712,
#  'JobTenure': 17,
#  'NetWorth': 15947,
#  'BaseInterestRate': 16902,
#  'InterestRate': 17284,
#  'MonthlyLoanPayment': 18846,
#  'TotalDebtToIncomeRatio': 18109,
#  'LoanApproved': 2,
#  'RiskScore': 73}

# %%
#find the count of unique values for target loan appproval column
data['LoanApproved'].value_counts()
# Out:
# LoanApproved
# 0    15220
# 1     4780
# Name: count, dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis(EDA)-Visualizing**

# %%
#EDA - Visualization
#univariate and bivariate analysis

plt.figure(figsize=(10,7))

#first plot
plt.subplot(1,2,1)
sns.histplot(data['CreditScore'],bins=30 , kde=True,color="r")
plt.title("credit score distribution")
plt.legend("credit score")

#second plot
plt.subplot(1,2,2)
sns.histplot(data['Age'],bins=30,kde=True,color="g")
plt.title("Age analysis")
plt.legend("age")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

#third plot

plt.subplot(1,2,1)
sns.scatterplot(data=data,x="CreditScore",y="LoanAmount")
plt.title('credit score vs Loan Amount')
plt.legend()

#Forth plot

plt.subplot(1,2,2)
sns.scatterplot(data=data,x="AnnualIncome",y="LoanDuration", color="g")
plt.title("Annnuval income vs Loan Duration")
plt.legend()
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,6))

#fifth plot
plt.subplot(1,2,1)
sns.boxplot(data=data,x="NumberOfDependents",y="SavingsAccountBalance")
plt.title("Number of dependants vs Saving account balance")
plt.legend()

#sixth plot
plt.subplot(1,2,2)
sns.boxplot(data=data,x="TotalLiabilities",y="TotalAssets",color="r")
plt.title("Total assets vs Total liabilities")
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

#seventh plot

plt.subplot(1,2,1)
sns.countplot(data=data,x="EmploymentStatus",color="y")
plt.title("Employment Status")
plt.xticks(rotation=90)

#eighth plot

plt.subplot(1,2,2)
sns.countplot(data=data ,x="EducationLevel",palette="Set2")
plt.title("Education status")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

#ninth plot
plt.subplot(1,2,1)
sns.countplot(data=data, x="MaritalStatus",color="teal")
plt.xticks(rotation=90)
plt.title("Maritail status")


#tenth plot
plt.subplot(1,2,2)
sns.countplot(data=data, x="LoanApproved",color="r")
plt.title( "Loan Approval Status")


plt.tight_layout()
plt.show()

# %%
#Multivariate plots

plt.figure(figsize=(17,8))
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
#second plot

plt.figure(figsize=(15,8))
sns.scatterplot(data=data,x='NetWorth',y='InterestRate',size='MonthlyIncome',hue ='MonthlyIncome',palette="coolwarm")
plt.title("Networth vs interest rate analysis based on Monthly Income")
plt.legend()
plt.show()

# %% [markdown]
# ## **Data Preprocessing -Data Clearning**

# %%
#handling missing values
#Clearning missing values in  categorial columns

from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='most_frequent')
data[cate_col]=impute.fit_transform(data[cate_col])

# %%
#Clearning missing values in numerial columns

from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
data[num_col]=imputer.fit_transform(data[num_col])

# %%
data.isnull().sum()
# Out:
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# NetWorth                      0
# BaseInterestRate              0
# InterestRate                  0
# MonthlyLoanPayment            0
# TotalDebtToIncomeRatio        0
# LoanApproved                  0
# RiskScore                     0
# dtype: int64

# %%
# Using z-Score check the outliers in numerical features

from scipy.stats import zscore

z_score = zscore(data[num_col])
outliers =np.where(np.abs(z_score)<3)
print("Outliers Removed",len(data)-len(outliers))
# Out:
# Outliers Removed 19998

# %%
#check the skewness

data[num_col].skew()
# Out:
# Age                           0.195654
# AnnualIncome                  2.092095
# CreditScore                  -0.596727
# Experience                    0.358713
# LoanAmount                    1.889139
# LoanDuration                  0.672002
# NumberOfDependents            0.693813
# MonthlyDebtPayments           1.723209
# CreditCardUtilizationRate     0.611741
# NumberOfOpenCreditLines       0.586750
# NumberOfCreditInquiries       1.036429
# DebtToIncomeRatio             0.610495
# BankruptcyHistory             4.117912
# PreviousLoanDefaults          2.767031
# PaymentHistory                0.220534
# LengthOfCreditHistory         0.006145
# SavingsAccountBalance         6.262137
# CheckingAccountBalance        4.882428
# TotalAssets                   5.482419
# TotalLiabilities              6.182936
# MonthlyIncome                 2.059872
# UtilityBillsPaymentHistory   -0.875216
# JobTenure                     0.430851
# NetWorth                      5.832586
# BaseInterestRate              0.494171
# InterestRate                  0.513268
# MonthlyLoanPayment            3.139966
# TotalDebtToIncomeRatio        2.646458
# LoanApproved                  1.224086
# RiskScore                    -0.162062
# dtype: float64

# %%
#visualizing the skewness


plt.figure(figsize=(16,11))

#first plot
plt.subplot(2,2,1)
sns.kdeplot(data["LoanAmount"])
plt.title("Loan Amount")

#second plot
plt.subplot(2,2,2)
sns.kdeplot(data["MonthlyDebtPayments"])
plt.title("Monthly debt payment")

#third plot
plt.subplot(2,2,3)
sns.kdeplot(data["AnnualIncome"])
plt.title("Annual Income")


#fourth plot
plt.subplot(2,2,4)
sns.kdeplot(data["NumberOfCreditInquiries"])
plt.title("Number of Credit in Quiries")
# Out:
# Text(0.5, 1.0, 'Number of Credit in Quiries')

# %%
-plt.figure(figsize=(16,11))
#fifth plot

plt.subplot(7,2,5)
sns.kdeplot(data["BankruptcyHistory"])

#sixth plot
plt.subplot(7,2,6)
sns.kdeplot(data["SavingsAccountBalance"])

#seven
plt.subplot(7,2,7)
sns.kdeplot(data["PreviousLoanDefaults"])

#eight

plt.subplot(7,2,8)
sns.kdeplot(data["CheckingAccountBalance"])

#ninth
plt.subplot(7,2,9)
sns.kdeplot(data["TotalAssets"])

#tenth
plt.subplot(7,2,10)
sns.kdeplot(data["TotalLiabilities"])

#11
plt.subplot(7,2,11)
sns.kdeplot(data["MonthlyIncome"])

#12
plt.subplot(7,2,12)
sns.kdeplot(data["NetWorth"])

#13
plt.subplot(7,2,13)
sns.kdeplot(data["MonthlyLoanPayment"])

#14
plt.subplot(7,2,14)
sns.kdeplot(data["TotalDebtToIncomeRatio"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-cbc3d642c79f> in <cell line: 0>()
# ----> 1 -plt.figure(figsize=(16,11))
#       2 #fifth plot
#       3
#       4 plt.subplot(7,2,5)
#       5 sns.kdeplot(data["BankruptcyHistory"])
#
# TypeError: bad operand type for unary -: 'Figure'
