# %% [markdown]
# <a href="https://colab.research.google.com/github/Harithamuralidharan/weather_Prediction/blob/main/Financial_Risk_for_Loan_Approval_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("loan_data.csv")
data
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2             NaN        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996         NaN        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                 0.0                  RENT    35000.0                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      41068 non-null  float64
#  1   person_gender                   41008 non-null  object
#  2   person_education                41097 non-null  object
#  3   person_income                   41001 non-null  float64
#  4   person_emp_exp                  40975 non-null  float64
#  5   person_home_ownership           41123 non-null  object
#  6   loan_amnt                       41124 non-null  float64
#  7   loan_intent                     41114 non-null  object
#  8   loan_int_rate                   41075 non-null  float64
#  9   loan_percent_income             41082 non-null  float64
#  10  cb_person_cred_hist_length      41057 non-null  float64
#  11  credit_score                    40997 non-null  float64
# ...
